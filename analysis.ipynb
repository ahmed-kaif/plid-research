# %% [markdown]
# ### Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import dataset

# %%
df = pd.read_csv('plid.csv')
df.head()
# Out:
#                      Timestamp    Id    Age     Sex        Occupation  \
# 0  2025/08/02 7:29:18 pm GMT+6  1201  36-40    Male     Manual worker
# 1  2025/08/02 7:30:34 pm GMT+6  1202  41-45    Male  Sedentary worker
# 2  2025/08/02 7:42:41 pm GMT+6  1203  36-40  Female  Sedentary worker
# 3  2025/08/02 7:44:01 pm GMT+6  1204  36-40    Male     Manual worker
# 4  2025/08/02 7:45:27 pm GMT+6  1205  56-60  Female  Sedentary worker
#
#   Low back pain Low back pain with Sciatica Bowel Bladder Involvement  \
# 0           Yes                        Left                        No
# 1           Yes                       Right                        No
# 2           Yes                        Both                       Yes
# 3           Yes                        Both                        No
# 4           Yes                       Right                        No
#
#   Straight Leg Raising Test Femoral Stretching Test  ... Operative Findings  \
# 0                Restricted                Negative  ...            Lateral
# 1                Restricted                Negative  ...       Central Disk
# 2                Restricted                Negative  ...      Extruded Disc
# 3                Restricted                Negative  ...       Central Disk
# 4                Restricted                Negative  ...            Lateral
#
#                                 Type of Operation   Annulus Pre operative ODI  \
# 0                                      Laminotomy    Intact               NaN
# 1                                      Laminotomy    Intact              77.0
# 2                                      Laminotomy  Ruptured               NaN
# 3                                      Laminotomy    Intact              88.0
# 4  Laminotomy;Unilateral fenestration & disectomy  Ruptured               NaN
#
#   Post operative ODI Pre operative NRS back pain Post operative NRS back pain  \
# 0                NaN                         NaN                          NaN
# 1                0.0                         6.0                          0.0
# 2                NaN                         NaN                          NaN
# 3               64.0                        10.0                          7.0
# 4                NaN                         NaN                          NaN
#
#   Surgery outcome according to Macnab criteria  Pre operative NRS leg pain  \
# 0                                          NaN                         NaN
# 1                                            E                         6.0
# 2                                          NaN                         NaN
# 3                                            P                         8.0
# 4                                          NaN                         NaN
#
#    Post operative NRS leg pain
# 0                          NaN
# 1                          0.0
# 2                          NaN
# 3                          6.0
# 4                          NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### analyze data

# %%
#check mising values
df.isnull().sum()
# Out:
# Timestamp                                         0
# Id                                                0
# Age                                               0
# Sex                                               0
# Occupation                                       10
# Low back pain                                     9
# Low back pain with Sciatica                       3
# Bowel Bladder Involvement                        10
# Straight Leg Raising Test                         9
# Femoral Stretching Test                          24
# Sensory Involvement                               6
# Motor involvement                                 6
# Knee Jerk                                        40
# Ankle Jerk                                       38
# Level of Disc Prolapse                            3
# Operative Findings                               11
# Type of Operation                                 7
# Annulus                                          37
# Pre operative ODI                               271
# Post operative ODI                              271
# Pre operative NRS back pain                     271
# Post operative NRS back pain                    271
# Surgery outcome according to Macnab criteria    271
# Pre operative NRS leg pain                      288
# Post operative NRS leg pain                     288
# dtype: int64

# %%
#check data types
df.dtypes
# Out:
# Timestamp                                        object
# Id                                                int64
# Age                                              object
# Sex                                              object
# Occupation                                       object
# Low back pain                                    object
# Low back pain with Sciatica                      object
# Bowel Bladder Involvement                        object
# Straight Leg Raising Test                        object
# Femoral Stretching Test                          object
# Sensory Involvement                              object
# Motor involvement                                object
# Knee Jerk                                        object
# Ankle Jerk                                       object
# Level of Disc Prolapse                           object
# Operative Findings                               object
# Type of Operation                                object
# Annulus                                          object
# Pre operative ODI                               float64
# Post operative ODI                              float64
# Pre operative NRS back pain                     float64
# Post operative NRS back pain                    float64
# Surgery outcome according to Macnab criteria     object
# Pre operative NRS leg pain                      float64
# Post operative NRS leg pain                     float64
# dtype: object

# %%
df.shape
# Out:
# (349, 25)

# %%
df['Knee Jerk'].unique()
# Out:
# array(['Intact', 'Absent', nan], dtype=object)

# %%
df['Surgery outcome according to Macnab criteria'].count()
# Out:
# np.int64(78)

# %%
df['Pre operative ODI'].count()
# Out:
# np.int64(78)

# %%
df['Post operative ODI'].count()
# Out:
# np.int64(78)

# %%
df['Pre operative NRS back pain'].count()
# Out:
# np.int64(78)

# %%
df['Post operative NRS back pain'].count()
# Out:
# np.int64(78)

# %%
df['Pre operative NRS leg pain'].count()
# Out:
# np.int64(61)

# %%
df['Post operative NRS leg pain'].count()
# Out:
# np.int64(61)

# %% [markdown]
# ### Imputation Phase

# %%
# Clone the dataframe
df_copy = df.copy()
# drop post operative columns
x1 = df_copy.drop(columns=['Post operative ODI', 'Post operative NRS back pain', 'Post operative NRS leg pain', 'Surgery outcome according to Macnab criteria'])
x1.columns
# Out:
# Index(['Timestamp', 'Id', 'Age', 'Sex', 'Occupation', 'Low back pain',
#        'Low back pain with Sciatica', 'Bowel Bladder Involvement',
#        'Straight Leg Raising Test', 'Femoral Stretching Test',
#        'Sensory Involvement', 'Motor involvement', 'Knee Jerk', 'Ankle Jerk',
#        'Level of Disc Prolapse', 'Operative Findings', 'Type of Operation',
#        'Annulus', 'Pre operative ODI', 'Pre operative NRS back pain',
#        'Pre operative NRS leg pain'],
#       dtype='object')

# %%
x1['Knee Jerk'] = x1['Knee Jerk'].fillna('Unknown')
x1['Ankle Jerk'] = x1['Ankle Jerk'].fillna('Unkwnown')

# %%
cat_cols = [
    'Occupation', 'Low back pain', 'Low back pain with Sciatica',
    'Bowel Bladder Involvement', 'Straight Leg Raising Test',
    'Femoral Stretching Test', 'Sensory Involvement', 'Motor involvement',
    'Knee Jerk', 'Ankle Jerk', 'Level of Disc Prolapse', 'Operative Findings',
    'Type of Operation', 'Annulus'
]

for col in cat_cols:
    print(f"{col}: {x1[col].unique()}")
# Out:
# Occupation: ['Manual worker' 'Sedentary worker' nan 'Housewife']
# Low back pain: ['Yes' 'No' nan]
# Low back pain with Sciatica: ['Left' 'Right' 'Both' nan]
# Bowel Bladder Involvement: ['No' 'Yes' nan]
# Straight Leg Raising Test: ['Restricted' nan 'Not Restricted']
# Femoral Stretching Test: ['Negative' nan 'Positive']
# Sensory Involvement: ['Involved' 'Not Involved' nan]
# Motor involvement: ['Involved' 'Not involved' nan]
# Knee Jerk: ['Intact' 'Absent' 'Unknown']
# Ankle Jerk: ['Intact' 'Absent' 'Unkwnown']
# Level of Disc Prolapse: ['L4/5' 'L5/S1' 'More than one level' 'L4/5;L5/S1' 'L3/4;L4/5'
#  'L4/5;L5/S1;More than one level' 'L5/S1;More than one level'
#  'L3/4;L4/5;L5/S1;More than one level' 'L3/4' 'L3/4;L5/S1' 'L2/3' nan
#  'L1/2;L5/S1']
# Operative Findings: ['Lateral' 'Central Disk' 'Extruded Disc' 'Paramedian Disc'
#  'Sequestrated Disc' nan 'Lateral;Extruded Disc' 'Hard Disc'
#  'Paramedian Disc;Extruded Disc' 'Central Disk;Extruded Disc'
#  'Central Disk;Hard Disc' 'Central Disk;Sequestrated Disc'
#  'Extruded Disc;Hard Disc' 'Extruded Disc;Sequestrated Disc']
# Type of Operation: ['Laminotomy' 'Laminotomy;Unilateral fenestration & disectomy'
#  'Fenestraction & Discectomy' 'Laminotomy and disectomy' nan
#  'Fenestraction & Discectomy;Fenestration & Foramenotomy'
#  'Unilateral fenestration & disectomy'
#  'Fenestration & Foramenotomy;Laminotomy and disectomy'
#  'Fenestraction & Discectomy;Laminotomy and disectomy'
#  'Fenestration & Foramenotomy' 'Hemilaminectomy'
#  'Fenestraction & Discectomy;Unilateral fenestration & disectomy'
#  'Fenestraction & Discectomy;Hemilaminectomy'
#  'Unilateral fenestration & disectomy;Laminotomy and disectomy'
#  'Fenestration & Foramenotomy;Unilateral fenestration & disectomy']
# Annulus: ['Intact' 'Ruptured' nan]
